# %% [markdown]
# <a href="https://colab.research.google.com/github/erichsiao1106/yolo3/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import keras.backend as K
from keras.layers import Input, Lambda
from train import yolo_body, get_anchors, create_model, get_classes
from yolo import YOLO
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from glob import glob

# %%
classes_path = 'model_data/aoi_classes.txt'
class_names = get_classes(classes_path)
num_classes = len(class_names)
anchors_path = 'model_data/yolo_anchors.txt'
anchors = get_anchors(anchors_path)

yolo = YOLO()
# Out:
# ep084-loss22.021-val_loss21.299.h5 model, anchors, and classes loaded.

# %%
path = np.random.choice(glob('dataset/train_img/*'), 1)[0]
print(path)
image = Image.open(path)
r_image = yolo.detect_image(image)
r_image.show()
plt.imshow(r_image)
# Out:
# dataset/train_img/crazing_121.jpg
# (200, 200) (416, 416)
# (416, 416, 3)
# Found 0 boxes for img
# 0.03898737020790577
